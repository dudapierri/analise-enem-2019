# %%
import pandas as pd

fonte= "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

dados= pd.read_csv(fonte)
#dados.head() # mostra o cabeçalho , caso as primeiras linhas 
#dados.shape # mostra que possui 127380 linhas e 136 colunas )
#dados[["SG_UF_RESIDENCIA","Q025"]] #SELECIONA MAIS DE UMA COLUNA 
#dados.columns.values   #RETORNA SÓ OS NOMES DAS COLUNAS
#dados["SG_UF_RESIDENCIA"].unique() # saber quais estados eu tenho presente na lista 
#len(dados["SG_UF_RESIDENCIA"].unique()) #saber o numero de estados que eu tenho na lista 
#dados["SG_UF_RESIDENCIA"].value_counts()# saber quantos elementos (daods que as pessoas se inscreveram) de cada estado eu tenho 
#dados["NU_IDADE"].value_counts() # saber o número de pessoas que se inscreveram com determinada idade 
#dados["NU_IDADE"].value_counts().sort_index() # ordernar o index 
#dados["NU_IDADE"].hist() # mostra um gráfico de idade (idade por volume de pessoas)
#dados["NU_IDADE"].hist(bins = 20) # mostra um gráfico de idade (idade por volume de pessoas) com mais caizinhas , ou seja, mais fiel, com maior precisão
#dados.query("IN_TREINEIRO == 1") # RETORNA os dados da tabela de apenas os alunos que são treineiros  
#dados.query("IN_TREINEIRO == 1") ["IN_TREINEIRO"]
#dados.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts().sort_index() # saber por idade de inscritos quem mais é treineiro # e depois ordenar o index
#dados["NU_NOTA_REDACAO"].hist(bins=20) # histogramas das notas de redação 
#dados["NU_NOTA_LC"].hist(bins=20) # histogramas das notas de linguagens e codigo
#dados["NU_NOTA_REDACAO"].mean() # calcular a media de cada uma dessas notas 
#dados["NU_NOTA_REDACAO"].std() # calcular desvio padrão de cada uma dessas notas 
provas = ["NU_NOTA_CN","NU_NOTA_CH", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_REDACAO" ]
dados[provas].describe()
dados[provas].boxplot(grid=True, figsize= (10,8)) # gráficos comparando as madianas das notas em relação a cada matéria
